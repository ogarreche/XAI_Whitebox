# %%
###########################################################################################################################################################################################################################################################################################################################
print('---------------------------------------------------------------------------------')
print('DNN DeepLIFT CICIDS local')
print('---------------------------------------------------------------------------------')
Trial_1 = [
' PSH Flag Count',
'Init_Win_bytes_forward',
' Destination Port',
' Avg Bwd Segment Size',
' Bwd Packet Length Mean',
' Packet Length Mean',
' min_seg_size_forward',
' Bwd Packet Length Min',
' Min Packet Length',
' Average Packet Size',
' Fwd Packet Length Min',
' Bwd Packets/s',
' Packet Length Std',
' Fwd Packet Length Mean',
' Avg Fwd Segment Size',
' Max Packet Length',
'Fwd Packets/s',
'Bwd Packet Length Max',
' Fwd Packet Length Max',
' Flow Duration'
]

Trial_2 = [
' PSH Flag Count',
'Init_Win_bytes_forward',
' Destination Port',
' Bwd Packet Length Min',
' Bwd Packet Length Mean',
' Average Packet Size',
' Packet Length Mean',
' min_seg_size_forward',
' Min Packet Length',
' Fwd Packet Length Min',
' Avg Bwd Segment Size',
' Packet Length Std',
' Fwd Packet Length Mean',
' Avg Fwd Segment Size',
' Max Packet Length',
'Bwd Packet Length Max',
' Bwd Packets/s',
' Fwd Packet Length Max',
'Fwd Packets/s',
' Flow Duration'
]

Trial_3 = [
' PSH Flag Count',
'Init_Win_bytes_forward',
' Destination Port',
' Bwd Packet Length Min',
' Bwd Packet Length Mean',
' Average Packet Size',
' Packet Length Mean',
' min_seg_size_forward',
' Min Packet Length',
' Fwd Packet Length Min',
' Avg Bwd Segment Size',
' Packet Length Std',
' Fwd Packet Length Mean',
' Avg Fwd Segment Size',
' Max Packet Length',
'Bwd Packet Length Max',
' Bwd Packets/s',
' Fwd Packet Length Max',
'Fwd Packets/s',
' Flow Duration',
' Flow IAT Max',
' Flow IAT Std',
' Flow IAT Mean',
' Packet Length Variance',
' Subflow Fwd Bytes',
'Total Length of Fwd Packets',
' Init_Win_bytes_backward',
' Fwd Header Length',
' Subflow Bwd Packets',
' Total Fwd Packets'

]

Intersection123 = set(Trial_1) & set(Trial_2) & set(Trial_3)

Total = len(Trial_1)

RF_stab = len(Intersection123)/Total
print(RF_stab)

print('---------------------------------------------------------------------------------')
print('DNN IG CICIDS Local')
print('---------------------------------------------------------------------------------')


Trial_1 = [
' min_seg_size_forward',
 ' Bwd Packet Length Min',
 ' Average Packet Size',
 ' Packet Length Mean',
 ' Bwd Packet Length Mean',
 ' Fwd Packet Length Min',
 ' Min Packet Length',
 ' Avg Bwd Segment Size',
 ' Fwd Packet Length Mean',
 ' Down/Up Ratio',
 ' Packet Length Std',
 'Bwd Packet Length Max',
 ' Fwd Packet Length Max',
 ' Avg Fwd Segment Size',
 ' Flow Duration',
 ' Flow IAT Max',
 ' Max Packet Length',
 ' Packet Length Variance',
 ' Subflow Fwd Bytes',
 'Total Length of Fwd Packets'
]

Trial_2 = [
' min_seg_size_forward',
 ' Bwd Packet Length Min',
 ' Average Packet Size',
 ' Packet Length Mean',
 ' Bwd Packet Length Mean',
 ' Fwd Packet Length Min',
 ' Min Packet Length',
 ' Avg Bwd Segment Size',
 ' Fwd Packet Length Mean',
 ' Down/Up Ratio',
 ' Packet Length Std',
 'Bwd Packet Length Max',
 ' Fwd Packet Length Max',
 ' Avg Fwd Segment Size',
 ' Flow Duration',
 ' Flow IAT Max',
 ' Max Packet Length',
 ' Packet Length Variance',
 ' Subflow Fwd Bytes',
 'Total Length of Fwd Packets'
]
Trial_3 =[
' min_seg_size_forward',
 ' Bwd Packet Length Min',
 ' Average Packet Size',
 ' Packet Length Mean',
 ' Bwd Packet Length Mean',
 ' Fwd Packet Length Min',
 ' Min Packet Length',
 ' Avg Bwd Segment Size',
 ' Fwd Packet Length Mean',
 ' Down/Up Ratio',
 ' Packet Length Std',
 'Bwd Packet Length Max',
 ' Fwd Packet Length Max',
 ' Avg Fwd Segment Size',
 ' Flow Duration',
 ' Flow IAT Max',
 ' Max Packet Length',
 ' Packet Length Variance',
 ' Subflow Fwd Bytes',
 'Total Length of Fwd Packets'
]
Intersection123 = set(Trial_1) & set(Trial_2) & set(Trial_3)

Total = len(Trial_1)

RF_stab = len(Intersection123)/Total
print(RF_stab)


print('---------------------------------------------------------------------------------')
print('DNN LRP CICIDS Local')
print('---------------------------------------------------------------------------------')


Trial_1 = [
' min_seg_size_forward',
 ' Bwd Packet Length Min',
 ' Packet Length Mean',
 ' Average Packet Size',
 ' Fwd Packet Length Min',
 ' Bwd Packet Length Mean',
 ' Avg Bwd Segment Size',
 ' Min Packet Length',
 ' Packet Length Std',
 ' Down/Up Ratio',
 ' Fwd Packet Length Mean',
 'Bwd Packet Length Max',
 ' Avg Fwd Segment Size',
 ' Fwd Packet Length Max',
 ' Max Packet Length',
 ' Flow Duration',
 ' Flow IAT Max',
 ' Packet Length Variance',
 ' Subflow Fwd Bytes',
 'Total Length of Fwd Packets'
]

Trial_2 = [
' min_seg_size_forward',
 ' Bwd Packet Length Min',
 ' Packet Length Mean',
 ' Average Packet Size',
 ' Fwd Packet Length Min',
 ' Bwd Packet Length Mean',
 ' Avg Bwd Segment Size',
 ' Min Packet Length',
 ' Packet Length Std',
 ' Down/Up Ratio',
 ' Fwd Packet Length Mean',
 'Bwd Packet Length Max',
 ' Avg Fwd Segment Size',
 ' Fwd Packet Length Max',
 ' Max Packet Length',
 ' Flow Duration',
 ' Flow IAT Max',
 ' Packet Length Variance',
 ' Subflow Fwd Bytes',
 'Total Length of Fwd Packets'

]
Trial_3 =[
' min_seg_size_forward',
 ' Bwd Packet Length Min',
 ' Packet Length Mean',
 ' Average Packet Size',
 ' Fwd Packet Length Min',
 ' Bwd Packet Length Mean',
 ' Avg Bwd Segment Size',
 ' Min Packet Length',
 ' Packet Length Std',
 ' Down/Up Ratio',
 ' Fwd Packet Length Mean',
 'Bwd Packet Length Max',
 ' Avg Fwd Segment Size',
 ' Fwd Packet Length Max',
 ' Max Packet Length',
 ' Flow Duration',
 ' Flow IAT Max',
 ' Packet Length Variance',
 ' Subflow Fwd Bytes',
 'Total Length of Fwd Packets'
]
Intersection123 = set(Trial_1) & set(Trial_2) & set(Trial_3)

Total = len(Trial_1)

RF_stab = len(Intersection123)/Total
print(RF_stab)
# Out:
# ---------------------------------------------------------------------------------
# Importing Libraries
# ---------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------
# Defining Metric Equations
# ---------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------
# DNN DeepLIFT CICIDS local
# ---------------------------------------------------------------------------------
# 1.0
# ---------------------------------------------------------------------------------
# DNN IG CICIDS Local
# ---------------------------------------------------------------------------------
# 1.0
# ---------------------------------------------------------------------------------
# DNN LRP CICIDS Local
# ---------------------------------------------------------------------------------
# 1.0
